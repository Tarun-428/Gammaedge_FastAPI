# %%
import pandas as pd

df = pd.read_csv("property_price_dataset_100_rows.csv")
df
# Out:
#     size_sqft  bedrooms  age_of_house  distance_from_city_km   price
# 0        1360         4             0                  13.60  353128
# 1        1794         3            18                  11.15  379779
# 2        1630         3             1                  19.71  347092
# 3        1595         1            25                  20.40  202144
# 4        2138         3            31                  26.06  395361
# ..        ...       ...           ...                    ...     ...
# 95       2562         2            29                  15.98  434179
# 96        564         2            37                  20.06   85593
# 97       3068         4            37                  13.63  551024
# 98       1867         5             7                  22.17  465825
# 99       1652         1            26                   2.38  232000
#
# [100 rows x 5 columns]

# %%
X = df.drop("price",axis=1)
Y = df["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test,pred))
rmse
# Out:
# np.float64(16355.729459044871)

# %%
for i,j in zip(y_test,pred):
    print(f"{i} {j:.2f}= {j-i}")
# Out:
# 426930 418787.76= -8142.238328773237
# 674399 671172.93= -3226.069391645724
# 142698 120982.74= -21715.257529705923
# 623891 621929.53= -1961.4688999236096
# 667674 673045.09= 5371.089580462081
# 418188 423308.22= 5120.223079185758
# 264845 248751.19= -16093.806547524378
# 114001 110627.92= -3373.0804562836274
# 391206 376240.39= -14965.613865231455
# 353128 385126.67= 31998.66902496078
# 531332 511865.37= -19466.62547181442
# 473985 469456.65= -4528.346650872671
# 295856 279105.94= -16750.062690089922
# 340285 366455.02= 26170.02324390324
# 430880 412996.54= -17883.46175166976
# 395361 372468.34= -22892.65511348803
# 445311 438388.01= -6922.993981863547
# 281264 277870.87= -3393.1296134465956
# 310150 279228.90= -30921.095539211587
# 395329 394681.65= -647.3519394556643

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(
    X_poly, y, test_size=0.2, random_state=42
)
model.fit(X_train,y_train)
pred = model.predict(X_test)

# %%
rmseP = np.sqrt(mean_squared_error(y_test,pred))

# %%
rmseP
# Out:
# np.float64(17242.050477578934)

# %%
for i,j in zip(y_test,pred):
    print(f"{i} {j:.2f} = {j-i}")
# Out:
# 426930 424710.41 = -2219.5926845740178
# 674399 650209.89 = -24189.111970602768
# 142698 133403.93 = -9294.068516134983
# 623891 627261.79 = 3370.7942423907807
# 667674 665572.79 = -2101.205640029628
# 418188 426779.36 = 8591.360826928634
# 264845 246650.89 = -18194.10889590194
# 114001 112275.49 = -1725.5093426618841
# 391206 387205.92 = -4000.0804630379425
# 353128 397182.84 = 44054.83868413721
# 531332 506911.23 = -24420.77417742065
# 473985 473215.40 = -769.603110349155
# 295856 289397.74 = -6458.256838352769
# 340285 371661.91 = 31376.906703865738
# 430880 434322.06 = 3442.061035005434
# 395361 369355.83 = -26005.17330752808
# 445311 433273.04 = -12037.962033649266
# 281264 274571.58 = -6692.422432608961
# 310150 290911.79 = -19238.208856014942
# 395329 399549.55 = 4220.546325840754
